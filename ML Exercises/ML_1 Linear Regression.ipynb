# %% [markdown]
# <a href="https://colab.research.google.com/github/thunderdog101/Machine-Learning/blob/main/ML_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
from vega_datasets import data

# %%
housing_data = pd.read_csv('https://raw.githubusercontent.com/cjflanagan/cs68/master/housing.csv')

# %%
housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
housing_data.shape
# Out:
# (1460, 81)

# %%
sns.lmplot(y= 'SalePrice',
           x = 'LotFrontage',
           data = housing_data)

# %%
y=housing_data['SalePrice']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
sns.scatterplot(y= 'SalePrice',
           x = 'LotArea',
           data = housing_data)

# %%
X = housing_data[['LotArea']]
X
# Out:
#       LotArea
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
# ...       ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
#
# [1460 rows x 1 columns]

# %%
X = sm.add_constant(X)
X
# Out:
#       const  LotArea
# 0       1.0     8450
# 1       1.0     9600
# 2       1.0    11250
# 3       1.0     9550
# 4       1.0    14260
# ...     ...      ...
# 1455    1.0     7917
# 1456    1.0    13175
# 1457    1.0     9042
# 1458    1.0     9717
# 1459    1.0     9937
#
# [1460 rows x 2 columns]

# %%
model = sm.OLS(y, X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     109.1
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):           1.12e-24
# Time:                        22:48:29   Log-Likelihood:                -18491.
# No. Observations:                1460   AIC:                         3.699e+04
# Df Residuals:                    1458   BIC:                         3.700e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.588e+05   2914.717     54.495      0.000    1.53e+05    1.65e+05
# ...

# %% [markdown]
# # Dummies - Genre

# %%
distrib_dummies = pd.get_dummies(housing_data[['Neighborhood']])
distrib_dummies
# Out:
#       Neighborhood_Blmngtn  ...  Neighborhood_Veenker
# 0                        0  ...                     0
# 1                        0  ...                     1
# 2                        0  ...                     0
# 3                        0  ...                     0
# 4                        0  ...                     0
# ...                    ...  ...                   ...
# 1455                     0  ...                     0
# 1456                     0  ...                     0
# 1457                     0  ...                     0
# 1458                     0  ...                     0
# 1459                     0  ...                     0
#
# [1460 rows x 25 columns]

# %%
X = X.join(distrib_dummies)
X
# Out:
#       const  LotArea  ...  Neighborhood_Timber  Neighborhood_Veenker
# 0       1.0     8450  ...                    0                     0
# 1       1.0     9600  ...                    0                     1
# 2       1.0    11250  ...                    0                     0
# 3       1.0     9550  ...                    0                     0
# 4       1.0    14260  ...                    0                     0
# ...     ...      ...  ...                  ...                   ...
# 1455    1.0     7917  ...                    0                     0
# 1456    1.0    13175  ...                    0                     0
# 1457    1.0     9042  ...                    0                     0
# 1458    1.0     9717  ...                    0                     0
# 1459    1.0     9937  ...                    0                     0
#
# [1460 rows x 27 columns]

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.573
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     76.99
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):          8.98e-244
# Time:                        22:56:13   Log-Likelihood:                -17923.
# No. Observations:                1460   AIC:                         3.590e+04
# Df Residuals:                    1434   BIC:                         3.603e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.626e+05   2692.060     60.414      0.000    1.57e+05    1.68e+05
# ...
